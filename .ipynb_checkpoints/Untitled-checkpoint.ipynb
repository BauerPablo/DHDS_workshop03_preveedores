# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegressionCV,  LogisticRegression
from sklearn.preprocessing import StandardScaler, binarize
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, precision_score, f1_score, roc_curve, auc, classification_report
from sklearn import tree

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
ruta_tat = 'data/VENDROS_TAT.csv'
ruta_vendors = 'data/VENDORS_NAMES_metrics.csv'
ruta_precios = 'data/CALIBRACIONES_2022.csv'

data_tat = pd.read_csv(ruta_tat, encoding='UTF-8', sep=',')
data_vendors = pd.read_csv(ruta_vendors, encoding='UTF-8', sep=',')
data_precios = pd.read_csv(ruta_precios, encoding='ANSI', sep=';', decimal=',')
# Out:
# C:\Users\ar037895\Anaconda3\envs\dhdsblend2022\lib\site-packages\IPython\core\interactiveshell.py:3194: DtypeWarning: Columns (70) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data_precios.sample(3)
# Out:
#      Fe.contabilizaci¢n  Centro de coste  N£mero de cuenta  \
# 1193          16/6/2022         10501007         700820001
# 598            3/3/2022         10501009         700820001
# 181           14/1/2022         10501009         700820001
#
#             Denominaci¢n  En moneda local centro de beneficio  \
# 1193  MNT-EQUIPOS TALLER                               450.00
# 598   MNT-EQUIPOS TALLER                               153.63
# 181   MNT-EQUIPOS TALLER                                18.56
#
#      Clave moneda ML CeBe  En moneda de la sociedad  \
# 1193                  USD                  57487.50
# 598                   USD                  17118.75
# 181                   USD                   2018.00
#
#      Clave moneda moneda sociedad  Acreedor Nombre del usuario  \
# 1193                          ARS  405794.0         BJADMIN_LO
# 598                           ARS  405792.0         BJADMIN_LO
# 181                           ARS  204208.0         BJADMIN_LO
#
#      Fecha de documento       Texto Documento compras  N§ doc.refer.
# 1193          16/6/2022  9446M18P01          R1132522     5005918941
# 598            3/3/2022        2323          R0004922     5005751505
# 181                   W     CM-6421          R0941321     5005672618

# %%
data_precios.rename(columns={'Documento compras':'order_number'}, inplace=True)

# %%
data_tat.sample(3)
# Out:
#          TAT  TAT7  TAT6  TAT5  TAT4   TAT3   TAT2  TAT1  order_number_id  \
# 14796   57.0   NaN   NaN  22.0  22.0   57.0   56.0   0.0           199478
# 9602   116.0   NaN   NaN   9.0   9.0  116.0  115.0   0.0           202541
# 8020    79.0  79.0   NaN  29.0  29.0    NaN    NaN   0.0           120287
#
#       order_number  ... EIN_arrival_date EIN_arrival_date_tz EIN_part_tool  \
# 14796     R1362622  ...              NaN                 NaN           NaN
# 9602      R1603222  ...              NaN                 NaN           NaN
# 8020      R4374819  ...              NaN                 NaN             Y
#
#           EIN_created_date EIN_created_date_tz EIN_airway_bill_date  \
# 14796                  NaN                 NaN                  NaN
# 9602                   NaN                 NaN                  NaN
# 8020   2020-02-20 00:00:00              +00:00  2020-01-29 00:00:00
#
#       EIN_airway_bill_date_tz            new_PARTNO         new_DESCRIPTION  \
# 14796                     NaN  ADTS553F-E0- SCAS-SR       AIR DATA TEST SET
# 9602                      NaN                  213C  VOLTIMETRO ANGULO FASE
# 8020                   +00:00                 D 81S              COMPARADOR
#
#       new_STATUS
# 14796          0
# 9602           0
# 8020           0
#
# [3 rows x 94 columns]

# %%
data_null = data_tat.apply(lambda x: x.isnull().sum()/data_tat.shape[0], axis=0)
data_null
# Out:
# TAT                        0.001003
# TAT7                       0.605082
# TAT6                       0.791174
# TAT5                       0.203076
# TAT4                       0.203076
#                              ...
# EIN_airway_bill_date       0.605082
# EIN_airway_bill_date_tz    0.605082
# new_PARTNO                 0.000000
# new_DESCRIPTION            0.000000
# new_STATUS                 0.000000
# Length: 94, dtype: float64

# %%
data_tat.dropna(how='all', axis=1)
# Out:
#         TAT  TAT7  TAT6  TAT5  TAT4  TAT3  TAT2  TAT1  order_number_id  \
# 0      12.0  12.0  12.0   NaN   NaN   NaN   NaN   NaN            47613
# 1      33.0   NaN   NaN  33.0  33.0   NaN   NaN   5.0            62347
# 2       4.0   NaN   NaN   NaN   NaN   NaN   NaN   4.0            67713
# 3      18.0   NaN   NaN  12.0  12.0   NaN   NaN  18.0            74221
# 4       6.0   NaN   NaN   6.0   6.0   NaN   NaN   0.0            76276
# ...     ...   ...   ...   ...   ...   ...   ...   ...              ...
# 14950  37.0   NaN   NaN  37.0  37.0   NaN   NaN   0.0           221104
# 14951   6.0   NaN   NaN   6.0   6.0   NaN   NaN   0.0           222035
# 14952   3.0   NaN   NaN   3.0   3.0   NaN   NaN   0.0           227645
# 14953   8.0   NaN   NaN   8.0   8.0   7.0   4.0   0.0           229035
# 14954  19.0   NaN   NaN   8.0   8.0  19.0  18.0   0.0           229035
#
#       order_number  ...     EIN_arrival_date EIN_arrival_date_tz  \
# 0      R0017144TRF  ...  2018-09-13 00:00:00              +00:00
# 1         R0285318  ...                  NaN                 NaN
# 2         R0667118  ...                  NaN                 NaN
# 3         R1102719  ...                  NaN                 NaN
# 4         R1251719  ...                  NaN                 NaN
# ...            ...  ...                  ...                 ...
# 14950     R3023322  ...                  NaN                 NaN
# 14951     R3095022  ...                  NaN                 NaN
# 14952     R0259923  ...                  NaN                 NaN
# 14953     R0369923  ...                  NaN                 NaN
# 14954     R0369923  ...                  NaN                 NaN
#
#       EIN_part_tool     EIN_created_date EIN_created_date_tz  \
# 0                 Y  2018-09-13 00:00:00              +00:00
# 1               NaN                  NaN                 NaN
# 2               NaN                  NaN                 NaN
# 3               NaN                  NaN                 NaN
# 4               NaN                  NaN                 NaN
# ...             ...                  ...                 ...
# 14950           NaN                  NaN                 NaN
# 14951           NaN                  NaN                 NaN
# 14952           NaN                  NaN                 NaN
# 14953           NaN                  NaN                 NaN
# 14954           NaN                  NaN                 NaN
#
#       EIN_airway_bill_date EIN_airway_bill_date_tz   new_PARTNO  \
# 0      2018-09-12 00:00:00                  +00:00         879B
# 1                      NaN                     NaN      AP-2703
# 2                      NaN                     NaN          L10
# 3                      NaN                     NaN     3277705.
# 4                      NaN                     NaN       7034-5
# ...                    ...                     ...          ...
# 14950                  NaN                     NaN       33-215
# 14951                  NaN                     NaN      4000 KG
# 14952                  NaN                     NaN       .800IN
# 14953                  NaN                     NaN  M22520/1-01
# 14954                  NaN                     NaN  M22520/1-01
#
#                     new_DESCRIPTION new_STATUS
# 0                         LCR METER          0
# 1                       DINAMOMETRO          0
# 2                       DINAMOMETRO          0
# 3                       DINAMOMETRO          0
# 4                        COMPARADOR          0
# ...                             ...        ...
# 14950   CINTA METRICA DE 3.5 MTS/12          0
# 14951                   DINAMOMETRO          0
# 14952  MICROMETRO DE INTERIOR AXIAL          0
# 14953    MANDRILADORA PINES DANIELS          0
# 14954    MANDRILADORA PINES DANIELS          0
#
# [14955 rows x 88 columns]

# %%
data_tat_filter = data_tat[[
    'TAT',
    'new_PARTNO',
    'new_DESCRIPTION',
    'order_number',
    'vendor_code',]]

# %%
data_tat_filter.sample(3)
# Out:
#          TAT      new_PARTNO             new_DESCRIPTION order_number  \
# 4342   573.0          MHC-05              WRENCH ADAPTER     P0705219
# 11634   32.0         0061BN1  COVER - PROBE ICE DETECTOR     P0257520
# 8688    17.0  T5-2002-104-00       TENSIOMETRO DE CABLES     R0083821
#
#       vendor_code
# 4342        2N935
# 11634       8M213
# 8688       AR0136

# %%
data_vendors_filtrado = data_vendors.drop(['COUNT','MEAN_of_TAT','STDEV_of_TAT'], axis=1)

# %%
ds_merge_vendor = data_tat_filter.merge(data_vendors_filtrado, how='left', on='vendor_code')

# %%
ds_merge_vendor.sample(3)
# Out:
#         TAT new_PARTNO new_DESCRIPTION order_number vendor_code  \
# 3424  117.0     768-20       ATENUADOR     R1086220       7VKY4
# 6593  192.0     125MEA         CALIBRE     R0808321      AR0011
# 3407   31.0      CMM-5       MANOMETRO     R2159219      AR0136
#
#                          vendor_name
# 3424                  AVC LABORATORY
# 6593  RUBEN HUGO COPPOLA E HIJOS SRL
# 3407        METROLOGOS ASOCIADOS SRL

# %%
ds_complete = ds_merge_vendor.merge(data_precios, how='left', on='order_number')

# %%
ds_complete
# Out:
#         TAT   new_PARTNO               new_DESCRIPTION order_number  \
# 0      12.0         879B                     LCR METER  R0017144TRF
# 1      33.0      AP-2703                   DINAMOMETRO     R0285318
# 2       4.0          L10                   DINAMOMETRO     R0667118
# 3      18.0     3277705.                   DINAMOMETRO     R1102719
# 4       6.0       7034-5                    COMPARADOR     R1251719
# ...     ...          ...                           ...          ...
# 15045  37.0       33-215   CINTA METRICA DE 3.5 MTS/12     R3023322
# 15046   6.0      4000 KG                   DINAMOMETRO     R3095022
# 15047   3.0       .800IN  MICROMETRO DE INTERIOR AXIAL     R0259923
# 15048   8.0  M22520/1-01    MANDRILADORA PINES DANIELS     R0369923
# 15049  19.0  M22520/1-01    MANDRILADORA PINES DANIELS     R0369923
#
#       vendor_code                     vendor_name Fe.contabilizaci¢n  \
# 0           0NUU5  BROADVIEW INSTRUMENTATION SERV                NaN
# 1          AR0011  RUBEN HUGO COPPOLA E HIJOS SRL                NaN
# 2          AR0011  RUBEN HUGO COPPOLA E HIJOS SRL                NaN
# 3          AR0011  RUBEN HUGO COPPOLA E HIJOS SRL                NaN
# 4          AR0011  RUBEN HUGO COPPOLA E HIJOS SRL                NaN
# ...           ...                             ...                ...
# 15045      AR0011  RUBEN HUGO COPPOLA E HIJOS SRL                NaN
# 15046      AR0011  RUBEN HUGO COPPOLA E HIJOS SRL                NaN
# 15047      AR0002    MITUTOYO SUL AMERICANA LTDA.                NaN
# 15048       7VKY4                  AVC LABORATORY                NaN
# 15049       7VKY4                  AVC LABORATORY                NaN
#
#        Centro de coste  N£mero de cuenta Denominaci¢n  \
# 0                  NaN               NaN          NaN
# 1                  NaN               NaN          NaN
# 2                  NaN               NaN          NaN
# 3                  NaN               NaN          NaN
# 4                  NaN               NaN          NaN
# ...                ...               ...          ...
# 15045              NaN               NaN          NaN
# 15046              NaN               NaN          NaN
# 15047              NaN               NaN          NaN
# 15048              NaN               NaN          NaN
# 15049              NaN               NaN          NaN
#
#        En moneda local centro de beneficio Clave moneda ML CeBe  \
# 0                                      NaN                  NaN
# 1                                      NaN                  NaN
# 2                                      NaN                  NaN
# 3                                      NaN                  NaN
# 4                                      NaN                  NaN
# ...                                    ...                  ...
# 15045                                  NaN                  NaN
# 15046                                  NaN                  NaN
# 15047                                  NaN                  NaN
# 15048                                  NaN                  NaN
# 15049                                  NaN                  NaN
#
#        En moneda de la sociedad Clave moneda moneda sociedad  Acreedor  \
# 0                           NaN                          NaN       NaN
# 1                           NaN                          NaN       NaN
# 2                           NaN                          NaN       NaN
# 3                           NaN                          NaN       NaN
# 4                           NaN                          NaN       NaN
# ...                         ...                          ...       ...
# 15045                       NaN                          NaN       NaN
# 15046                       NaN                          NaN       NaN
# 15047                       NaN                          NaN       NaN
# 15048                       NaN                          NaN       NaN
# 15049                       NaN                          NaN       NaN
#
#       Nombre del usuario Fecha de documento Texto  N§ doc.refer.
# 0                    NaN                NaN   NaN            NaN
# 1                    NaN                NaN   NaN            NaN
# 2                    NaN                NaN   NaN            NaN
# 3                    NaN                NaN   NaN            NaN
# 4                    NaN                NaN   NaN            NaN
# ...                  ...                ...   ...            ...
# 15045                NaN                NaN   NaN            NaN
# 15046                NaN                NaN   NaN            NaN
# 15047                NaN                NaN   NaN            NaN
# 15048                NaN                NaN   NaN            NaN
# 15049                NaN                NaN   NaN            NaN
#
# [15050 rows x 19 columns]

# %%
ds_complete.rename(columns={'new_PARTNO':'part_number','new_DESCRIPTION':'description', 'En moneda local centro de beneficio':'costo_USD', 'Clave moneda ML CeBe':'unidad_USD', 'En moneda de la sociedad':'costo_ARS', 'Clave moneda moneda sociedad':'unidad_ARS'}, inplace=True)

# %%
ds_complete
# Out:
#         TAT  part_number                   description order_number  \
# 0      12.0         879B                     LCR METER  R0017144TRF
# 1      33.0      AP-2703                   DINAMOMETRO     R0285318
# 2       4.0          L10                   DINAMOMETRO     R0667118
# 3      18.0     3277705.                   DINAMOMETRO     R1102719
# 4       6.0       7034-5                    COMPARADOR     R1251719
# ...     ...          ...                           ...          ...
# 15045  37.0       33-215   CINTA METRICA DE 3.5 MTS/12     R3023322
# 15046   6.0      4000 KG                   DINAMOMETRO     R3095022
# 15047   3.0       .800IN  MICROMETRO DE INTERIOR AXIAL     R0259923
# 15048   8.0  M22520/1-01    MANDRILADORA PINES DANIELS     R0369923
# 15049  19.0  M22520/1-01    MANDRILADORA PINES DANIELS     R0369923
#
#       vendor_code                     vendor_name Fe.contabilizaci¢n  \
# 0           0NUU5  BROADVIEW INSTRUMENTATION SERV                NaN
# 1          AR0011  RUBEN HUGO COPPOLA E HIJOS SRL                NaN
# 2          AR0011  RUBEN HUGO COPPOLA E HIJOS SRL                NaN
# 3          AR0011  RUBEN HUGO COPPOLA E HIJOS SRL                NaN
# 4          AR0011  RUBEN HUGO COPPOLA E HIJOS SRL                NaN
# ...           ...                             ...                ...
# 15045      AR0011  RUBEN HUGO COPPOLA E HIJOS SRL                NaN
# 15046      AR0011  RUBEN HUGO COPPOLA E HIJOS SRL                NaN
# 15047      AR0002    MITUTOYO SUL AMERICANA LTDA.                NaN
# 15048       7VKY4                  AVC LABORATORY                NaN
# 15049       7VKY4                  AVC LABORATORY                NaN
#
#        Centro de coste  N£mero de cuenta Denominaci¢n  costo_USD unidad_USD  \
# 0                  NaN               NaN          NaN        NaN        NaN
# 1                  NaN               NaN          NaN        NaN        NaN
# 2                  NaN               NaN          NaN        NaN        NaN
# 3                  NaN               NaN          NaN        NaN        NaN
# 4                  NaN               NaN          NaN        NaN        NaN
# ...                ...               ...          ...        ...        ...
# 15045              NaN               NaN          NaN        NaN        NaN
# 15046              NaN               NaN          NaN        NaN        NaN
# 15047              NaN               NaN          NaN        NaN        NaN
# 15048              NaN               NaN          NaN        NaN        NaN
# 15049              NaN               NaN          NaN        NaN        NaN
#
#        costo_ARS unidad_ARS  Acreedor Nombre del usuario Fecha de documento  \
# 0            NaN        NaN       NaN                NaN                NaN
# 1            NaN        NaN       NaN                NaN                NaN
# 2            NaN        NaN       NaN                NaN                NaN
# 3            NaN        NaN       NaN                NaN                NaN
# 4            NaN        NaN       NaN                NaN                NaN
# ...          ...        ...       ...                ...                ...
# 15045        NaN        NaN       NaN                NaN                NaN
# 15046        NaN        NaN       NaN                NaN                NaN
# 15047        NaN        NaN       NaN                NaN                NaN
# 15048        NaN        NaN       NaN                NaN                NaN
# 15049        NaN        NaN       NaN                NaN                NaN
#
#       Texto  N§ doc.refer.
# 0       NaN            NaN
# 1       NaN            NaN
# 2       NaN            NaN
# 3       NaN            NaN
# 4       NaN            NaN
# ...     ...            ...
# 15045   NaN            NaN
# 15046   NaN            NaN
# 15047   NaN            NaN
# 15048   NaN            NaN
# 15049   NaN            NaN
#
# [15050 rows x 19 columns]

# %%
ds_complete = ds_complete.drop(['Denominaci¢n','N£mero de cuenta','Acreedor','Nombre del usuario','Fecha de documento','N§ doc.refer.'], axis=1)

# %%
ds_complete = ds_complete.dropna(how='any', axis=0)

# %%
ds_complete
# Out:
#          TAT part_number                   description order_number  \
# 39      15.0      .800IN  MICROMETRO DE INTERIOR AXIAL     R0691121
# 50      45.0       43191                      PARALELA     R1788221
# 51      80.0  HCS203803C                       BALANZA     R0044022
# 52      13.0   UX100-003        DATALOGGER MARCA ONSET     R0433922
# 53      42.0   UX100-003        DATALOGGER MARCA ONSET     R0433922
# ...      ...         ...                           ...          ...
# 15025   58.0       215-2                    COMPARADOR     R1707521
# 15026   23.0      33-158                 CINTA METRICA     R1937121
# 15029   63.0       4 IN.                    MICROMETRO     R2110821
# 15032   41.0      10-PSI                     MANOMETRO     R0170622
# 15038  160.0      436-15                    MICROMETRO     R1231222
#
#       vendor_code                       vendor_name Fe.contabilizaci¢n  \
# 39         AR0002      MITUTOYO SUL AMERICANA LTDA.           1/4/2022
# 50         AR0011    RUBEN HUGO COPPOLA E HIJOS SRL          28/1/2022
# 51         AR0507                      CHACOMA S.A.           8/4/2022
# 52          551CB  TRESCAL ESPAÑA DE METROLOGIA SLU          18/4/2022
# 53          551CB  TRESCAL ESPAÑA DE METROLOGIA SLU          18/4/2022
# ...           ...                               ...                ...
# 15025      AR0011    RUBEN HUGO COPPOLA E HIJOS SRL          25/1/2022
# 15026      AR0136          METROLOGOS ASOCIADOS SRL          21/1/2022
# 15029      AR0011    RUBEN HUGO COPPOLA E HIJOS SRL           9/3/2022
# 15032      AR0011    RUBEN HUGO COPPOLA E HIJOS SRL           1/4/2022
# 15038      AR0011    RUBEN HUGO COPPOLA E HIJOS SRL         28/11/2022
#
#        Centro de coste  costo_USD unidad_USD  costo_ARS unidad_ARS       Texto
# 39          10501009.0     106.03        USD   12300.00        ARS      .800IN
# 50          10501009.0      56.48        USD    6213.00        ARS       43191
# 51          10501009.0     159.91        USD   18750.00        ARS  HCS203803C
# 52          10501009.0      97.58        USD   11311.02        ARS   UX100-003
# 53          10501009.0      97.58        USD   11311.02        ARS   UX100-003
# ...                ...        ...        ...        ...        ...         ...
# 15025       10501009.0      36.54        USD    4001.00        ARS       215-2
# 15026       10501009.0      70.73        USD    7710.00        ARS      33-158
# 15029       10501009.0      34.99        USD    3980.00        ARS       4 IN.
# 15032       10501009.0      44.48        USD    5160.00        ARS      10-PSI
# 15038       10501009.0      71.24        USD   12236.00        ARS      436-15
#
# [1850 rows x 13 columns]

# %%
ds_complete.description.value_counts()
# Out:
# MICROMETRO                              124
# DINAMOMETRO                              98
# COMPARADOR                               77
# TORQUIMETRO                              62
# MULTIMETRO DIGITAL                       53
#                                        ...
# LOOP RESISTANCE TESTER AIRLINER SET       1
# DIGITAL MICRO-OHMMETER                    1
# CALIBRADOR DE PRESION                     1
# COMPARADOR A PALANCA (PALPADOR )          1
# PROGRAMMABLE POWER                        1
# Name: description, Length: 391, dtype: int64

# %%
ds_complete.description.unique()
# Out:
# array(['MICROMETRO DE INTERIOR AXIAL', 'PARALELA', 'BALANZA',
#        'DATALOGGER MARCA ONSET', 'FLUJOMETRO', 'PARALELAS', 'MICROMETRO',
#        'COMPARADOR', 'ALESAMETRO OPTICO', 'TORQUIMETRO',
#        'CONFIGURABLE DISPLAY', 'DUROMETRO ANALOGICO - RANGO 0-100',
#        'INDICADOR DE TEMP.', 'CINTA METRICA 2 METROS', 'MONITOR',
#        'TST VOR/ILS/COMUNIC. RAMP TEST NAV', 'DINAMOMETRO',
#        'CINTA PROMEDIADORA', 'CRIMPING TOOL', 'PENETRADOR DE DIAMANTE',
#        'PROTRACTOR', 'MULTIMETRO DIGITAL FLUKE', 'FOTOMETRO',
#        'SONDA DE ESPESOR', 'MANDRILADORA PINES DANIELS',
#        'CONTROL DE TEMPERATURA & TERMOCUPLA', '3M718', 'FUENTE',
#        'MEDIDOR DE ANGULOS', 'MULTI-PRODUCT CALIBRATOR', 'SET DE PESAS',
#        'KIT GAUGE ASSY PUSH PULL', 'MICROMETRO DE ROSCA', 'MANOMETRO',
#        'DETECTOR MULTIPLE DE GAS', 'TORQUIMETRO AJUSTABLE STURTEVANT',
#        'MICROMETRO DE PROFUNDIDAD', 'ALESAMETRO CON COMPARADOR',
#        'FUENTE DE ALIMENTACION', 'MULTIMETRO DIGITAL',
#        'MULTIMETRO DIGITAL HP (KEYSIGHT)', 'CALIBRE',
#        'VOLTIMETRO CC 0 A 10 V', 'TRANSDUCTOR DE PRESION', 'GAUSSIMETRO',
#        'TERMOHIGROGRAFO', 'TORQUIMETRO AISLADO', '5527O-OHMMETER',
#        'STANDARD CONDUCTIVIDAD', 'VOLTIMETRO DC', 'LCR METER', 'REGLA',
#        'MULTIMETRO ANALOGICO', 'SENSOR FOTOMETRO',
#        'OPTICAL MICROMETER MONOCLE', 'TERMOHIGROMETRO', 'CINTA METRICA',
#        'OSCILOSCOPIO DIGITAL COLOR KEYSIGHT', 'MANOVACUOMETRO',
#        'MANDRILADORA DE CABLES', 'PINZA AMPEROMETRICA',
#        'SENSOR DE LUZ UV', 'BLOQUE DUREZA', 'BONDMASTER  1000E+',
#        'JUEGO DE SONDAS', 'DUROMETRO', 'SCOPEMETER', 'DECADA RESISTENCIA',
#        'TORQUIMETRO AJUSTABLE CDI', 'MICROMETRO DE INTERIOR',
#        'AIR DATA TEST SET - PITOT Y ESTATICA', 'PROX CARD CAL',
#        'CELDA DE CARGA', 'SONDA TEMP. Y HUMEDAD TESTO SAVERIS',
#        'CALIBRE ANALÓGICO STARRETT', 'DECADA RESISTENCIAS',
#        'CALIBRE DIGITAL STARRETT', 'BANCO DE PRUEBAS',
#        'MEDIDOR DE EXTERIOR CON RELOJ', 'OPTOMETER',
#        'NIVEL LINEAL DIGITAL PROTRACTOR', 'MANDRILADORA PINES',
#        'MEDIDOR DIGITAL', 'RESISTENCIA VARIABLE HELIPOT',
#        'AMPERÍMETRO CC 0 A 50 A', 'AIRFLOW ANEMOMETER',
#        'MULTIMETRO DIGITAL PORTATIL FLUKE', 'CRONOMETRO DIGITAL',
#        'IN-SERVICE INSPECTION GAGE',
#        'FUENTE DE ALIMENTACION BK PRECISION', 'FLUJOMETRO DE TURBINA',
#        'BIOSYSTEMS TRAVEL PANEL 50MP', 'TERMOMETRO DIGITAL',
#        'DATALOGGER TEMP HUMEDAD TESTO', 'MICROPHONE SOUND QTG',
#        'MEGOHMETRO', 'MICROMETRO DE RANURAS', 'SOUND LEVEL METER',
#        'RIGGING BAR ELEVAT', 'HYPOT III AC/DC',
#        'MEDIDOR DE NIVEL DE SONIDO', 'GAGE FORCE GEARBOX ROLLER BEARING',
#        'CALIBRE DE PROFUNDIDAD', 'SOUND LEVEL CALIBRATOR IET-LABS',
#        'CRONOMETRO', 'MIKROOHMMETER', 'INFLATION TOOL - STRUT',
#        'TRACEABLE™ JUMBO-DIGIT STOPWATCH', 'MILLIVOLTMETER',
#        'DIGITAL TEMPERATURE CONTROLLER', 'AC/DC HIGH POT TESTER',
#        'GENERADOR DE AUDIO', 'CONTROL TEMPERATURA PROCESO N°59',
#        'TERMOMETRO', 'PENETRADOR DE ESFERA DE ACERO', 'PINZA PELA CABLES',
#        'DIGITAL POWER ANALYZER', 'RA SCANNER', 'TENSIOMETRO DE CABLE',
#        'MEDIDOR DE ESPESORES', 'SCANNER RA2000',
#        'VOLTIMETRO AC ANALÓG. HP', 'CONDUCTIVITY STANDAR', 'BCO.PBA.ESL',
#        'TERMOMETRO INFRAROJO', 'CONTROLADOR LIMITADOR DE TEMPERATURA',
#        'TERMOMETRO DIGITAL CON REGISTRADOR', 'MEDIDOR DE POTENCIA',
#        'PATRÓN DE ELECTRICIDAD', 'DIGITAL MICRO-OHMMETER',
#        'TORQUIMETRO 70 IN/LBS', 'BEACON TESTER', 'MARMOL',
#        'PENETRADOR DE ESFERA', 'PIEZA', 'MICROMETRO DE EXTERIORES',
#        'CALIBRE PASA NO PASA', 'EQUIPO DE RAYOS X', 'RAMP TEST SYSTEM',
#        'EQUIPO ULTRASONIDO', 'INTERNAL FUNCT.SIZE THREAD ROLL GAGE',
#        'AMPERIMETRO DC', 'MEDIDOR DE ANGULOS PROTRACTOR', 'PESAS',
#        'MEDIDOR DE ANGULOS - PROTRACTOR', 'TERMOMETRO DE VIDRIO',
#        'CSCANNER', 'STANDBY COMPASS CALIBRATOR SET', 'ALESAMETRO',
#        'MEDIDOR DE RCL', 'TERMISTOR', 'RELOJ COMPARADOR',
#        'AMPERIMETRO AC', 'LOOP CONTROLLER', 'SONDAS', 'TENSIOMETRO',
#        'PROYECTOR DE PERFILES', 'FUENTE DE ALIMENTACION DC XANTREX',
#        'ANILLO', 'WRIST STRAP TESTER', 'TESTER TORQUE',
#        'TRANSDUCTOR PRESION', 'BONDING METER', 'MICROMETRO EXTERIORES',
#        'EDDY CURRENT', 'GEN.S,XPDR/TCAS/DME', 'CALIBRADOR',
#        'SURFACE TESTER (MEDIDOR RUGOSIDAD)', 'COMPARADOR A TIJERA',
#        'TDS DIGITAL METER', 'SHUNT', 'PARALELA DE CONTROL', 'MEGHOMETRO',
#        'CONTROL TEMPERATURA PROCESO N°26', 'CAMARA TERMOGRAFICA',
#        'MANDRILADORA TERMIN.', 'POWER SUPPLY DC', 'ATENUADOR',
#        'STANDARD CONDUCTIVITY', 'PENETRADOR 120° HRC-A-D',
#        'TEST EQUIPMENT, RAIN REPELLENT SYST',
#        'TESTER ESTATICA Y DINAMICA', 'OSCILOSCOPIO',
#        'AMPERIMETRO 0 A 100 A CC', 'VOLTIMETRO', 'EQUIPO DE CADMIO LOCAL',
#        'HERRAMIENTA ESPECIAL', 'MILLIOHMETRO DIGITAL', 'PESA',
#        'EPOCH 650', 'TEST SET', 'MANDRILADORA DE CABLES AMP',
#        'BOROSCOPIO', 'HEATING SYSTEM', 'DECADA DE RESISTENCIAS',
#        'BALANZA DIGITAL 620 GR', 'EQUIPO EDDY CURRENT',
#        'MICROMETRO DE ROSCAS', 'MEGOHMETRO DIGITAL PORTATIL EXTECH',
#        'TORQUE WRENCH', 'CALIBRE ANALÓGICO', 'ESTACIÓN DE SOLDADURA PACE',
#        'PEINE DE ROSCA', 'PRESSURE CALIBRATOR',
#        'DECADA DIVISOR DE TENSION', 'MULTI-FUNCTION GENERATOR',
#        'ARBITRARY WAVEFORM GENERATOR', 'DINAMOMETRO ANALÓGICO 25LBF',
#        'ULTRASONIC TEST SET DUKANE', 'RETRACTION DELAY VALVE KIT',
#        'CRONOMETRO DIGITAL PORTATIL', 'RAMP TEST T-CAS',
#        'AIR VELOCITY METER', 'VACUOMETRO', 'CRISTAL OPTICO',
#        'SHAFT ENCODER READOUT BOX', 'MANDRILADORA DE CABLE',
#        'TENSIOMETRO DE CABLES', 'BALANZA PORTATIL', 'MANOMETRO DIGITAL',
#        'TERMORESISTENCIA', 'GALGAS CILINDRICAS', 'VARILLA',
#        'RAMP TEST ATC', 'CUÁDRUPLE TIMER ASCEND /  DESCEND',
#        'COMPARADOR DIGITAL 0-100 MM', 'FOTOFLUORIMETRO',
#        'CALIBRATION UNIT', 'MICROMETRO DE PUNTAS', 'ANALIZADOR-CARGADOR',
#        'TESTER AND ANALYSER FOR ULD', 'CALIBRE PIE A COLIZA',
#        'RTD THERMOMETER', 'MICROMETRO DE EXTERIORES DE 0-1INCH',
#        'PINZA AMPEROMETRICA EXTECH', 'ANALIZADOR TRIFASICO ENERGÍA FLUKE',
#        'NIVEL DIGITAL PROTRACTOR', 'COMPARADOR A PALANCA (PALPADOR)',
#        'DECADA RESISTENCIA IET LAPS', 'CALIBRADOR DE ROSCA EXTERNA',
#        'BOND TESTER', 'WEATHER STATION W/EXTERNAL SENSOR',
#        'HIPOT TESTER DIGITAL SPS ELECTRONIC', 'ESTACION METEOROLOGICA',
#        'TORQUIMETRO AISLADO CEMENTEX', 'MICROMETRO OPTICO DE PROFUNDIDAD',
#        'PRESSURE TRANSM DIGICOMP 3 A5000PSI', 'CRIMP TOOL',
#        'PUENTE MEGOHMETRO', 'DATA LOGGER', 'NIVEL',
#        'RADOME MOISTURE IND.', 'ADAPTER COAXIAL-WAVEGUIDE KEYSIGHT',
#        'AUDIO ANALIZER', 'ANILLO PATRON DE ROSCA',
#        'ALESOMETRO CON COMPARADOR', 'MEDIDOR RESIST AISLAMIENTO',
#        'DINAMOMETRO DIGITAL', 'TERMOCUPLA', 'CALIBRE DE ALTURA',
#        'BALANZA PESAJE DE AVIONES', 'TEMPCAL TESTER',
#        'MONITOR DE RADIACION', 'RUGGED RTD PROBE 6"', 'BOX',
#        'DIGITAL TEST METER KIT', 'TRUE RMS MULTIMETER IR THERMOMETER',
#        'ALESOMETRO', 'DIGITAL RADIO ALTIMETER TEST SET',
#        'INDICADOR DIGITAL', 'CINTA DE MEDIR',
#        'AMPERIMETRO ANALOGICO (DC)', 'MICROMETRO DE EXT. RANGO :20-21IN',
#        'VOLTIMETRO ANALOGICO (DC)', 'INDUCTION HEADER',
#        'DATA BUS ANALYZER', 'SONDA (GALGA) SET STARRETT 66',
#        'SIGNAL GENERATOR', 'MANOMETRO 5000 PSI', 'PROBETA',
#        'DATA ADQUISITION GAGING EQUIP.', 'DETECTOR DE EXFOLIACION',
#        'MULTIMETRO ANALÓG. PORTATIL SIMPSON', 'AIR FLOW TEST SET',
#        'DIGITAL TIMER CRONOMETRO', 'CONTROLLER',
#        'INDICADOR POSICION ANGULAR', 'SHUNT 1000 AMP 50 MV',
#        'PNEUMATIC CRIMP TOOL  M22520/23-1', 'DC POWER SUPPLY',
#        'MICROMETRO C/COMPARADOR', 'MICROMETRO P/ESTRIA',
#        'COMPARADOR A PALANCA ( PALPADOR )', '3KW AC ELECTRONIC LOAD',
#        'LENTE GRADUADA', 'PLANO DE MEDICIÓN', 'HYDRAULIC LOAD CELL',
#        'RAMP-TEST DE VOR', 'MANDRILADORAS DE CABLES',
#        'LOOP RESISTANCE TESTER AIRLINER SET ',
#        'MEGOHMETRO ANALÓGICO GENRAD', 'FLAP SPEED PRO',
#        'UNIVERSAL FREQUENCY COUNTER TIME', 'INSULATION MULTIMETER',
#        'BOND TESTING FLAW DETECTOR', 'TORQUIMETRO 3–15 IN-LB',
#        'CAMARA IONISACION', 'PROGRAMMABLE POWER', 'SENSOR DE LUZ VISIBLE',
#        'GLASS THERMOMETER', 'DINAMOMETRO ANALÓGICO 100 LBF',
#        'CALIBRE DIGITAL', 'VISCOSIMETRO', 'ULTRASONIC FLAW DETECTOR',
#        'BALANZA MANOMETRICA', 'TORQOMETER 192 IN-OZ/12 IN-LB',
#        'MANOMETRO DIGITAL 0 - 15 PSI', 'ANALIZADOR DE DISTORSION',
#        'CONTROLADOR DIGITAL + TERMOPAR',
#        'INTERNAL 8 PITCH UN60 V THREAD ROLLS',
#        'MULTIMETRO DIGITAL PORTATIL EXTECH',
#        'MICROMETRO DE EXT. RANGO : 22-23 IN',
#        'MEDIDOR DE DUREZA PORTATIL',
#        'MICROMETRO EXTERIOR DIGITAL STARRETT',
#        'TORQUIMETRO RANGO 96 IN-OZ', 'CHARGE AMPLIFIER', 'GONIOMETRO',
#        'ANALIZADOR DE DATOS', 'CALIBRADOR DE PRESION',
#        'JUEGO DE SONDAS LARGAS', 'CONTROLADOR DIGITAL',
#        'BOND TESTING FLAW DE', 'TERMOHIGROMETRO/CON REMOTO',
#        'HORNO DE BLOQUE SECO', '16:64PR PHASED ARRAY ACQ.U/1 UT HD',
#        'VOLTIMETRO ANGULO FASE', 'COIL', 'TORQUIMETRO 13 IN/LBS',
#        'AMPERIMETRO JEWELL 0 A 750 A', 'MANOMETRO 0-60 PSI',
#        'TACOMETRO CONTACTO / OPTICO PORTATIL',
#        'MANDRILADORA DE PINES DANIELS',
#        'COMPARADOR A PALANCA (PALPADOR )', 'CONTROL DIGITAL + TERMOPAR',
#        'CONTROL TEMPERATURA  PROCESO 54', 'CALIBRE P/MEDIR ENGRANAJES',
#        'ANALIZADOR DE ESPECTRO', 'CALIBRE DE ALTURA DIGITAL STARRETT',
#        'CONTADOR DE FREQUENCIA', 'BLOQUE DE DUREZA', 'TEST SET 50 TM',
#        'DINAMÓMETRO', 'LUMINANCIMETRO', 'PLATINUM RESISTANCE THERMOMETER',
#        'GAUSSMETER', 'IFR ATC-601 RAMP TEST SET', 'FLASH MEASURING GUN',
#        'SENSOR, ILUMINANCE, LUX Y/O FC',
#        'INTERNAL 12 PITCH UN60 V THREAD ROLL',
#        'INTERNAL 16 PITCH UN60 V THREAD ROLL',
#        'INDUSTRIAL GRADE FLOWMETER', 'PESA PATRON ARSA',
#        'VACUUM & PRESSURE TEST KIT IGGS',
#        'TRAMMEL BAR - STABILIZER TRIM ACTUAT', 'ACOPLADOR DIRECCIONAL',
#        'TORQUIMETRO 20.5 IN/LBS', 'MICROMETRO OPTICO', 'MILLIOHMMETER',
#        'DUROMETRO PORTATIL', 'CONJUNTO FLUJOMETRO', 'KIT PRUEBA RESIST.',
#        'MEGOHMETRO / IR TESTER QUARTECH', 'TEMPORIZADOR',
#        'THERMOMETER DUAL DIGITAL', 'RTSX400F',
#        'FUENTE DE ALIMENTACION HP (KEYSIGHT)', 'TESTER ULTRASONIDO',
#        'GRAFICADOR CON SENSOR', 'NORTEC 600 EDDY CURRENT FLAW DETECT',
#        'DIGITAL IGNITER TESTER', 'BCO. PBA. FLUJOMETRO',
#        'TORQUIMETRO ANALÓGICO PROTO', 'MEGOHMETRO - HI-POT',
#        'CILINDRO DE ALTA PRESION', 'SYSTEM SWITCH/MULTIMETER',
#        'SCAN DETECTOR', 'DECADE RESISTOR 1- 100 KOHM',
#        'CONTROL TEMPERATURA PROCESO N°57',
#        'FUENTE DE ALIMENTACION KEYSIGHT', 'CAJA DE RESISTORES',
#        'MICROMETRO DE PLATILLO'], dtype=object)

# %%
def  mag_identify(desc):
    if 'TORQUIMETRO'in desc or 'TORQUÍMETRO' in desc:
        desc = 'TORQUE'
    elif 'DINAM' in desc or 'CALIBRE' in desc or 'NIVEL' in desc or 'PENETRADOR' in desc or 'MICROMETRO'in desc or 'MICRÓMETRO' in desc or 'MANDRILADORA' in desc or 'SONDAS' in desc or 'DUROMETRO' in desc or 'PARALELA' in desc or 'BALANZA' in desc or 'COMPARADOR' in desc or 'CINTA' in desc or 'DUROMETRO' in desc or 'CRIMPING' in desc or 'DUREZA' in desc:
        desc = 'DIMENSIONAL'
    elif 'MANOMETRO'in desc or 'MANÓMETRO' in desc or 'VACU' in desc or 'PRESSURE' in desc:
        desc = 'PRESIÓN'
    elif 'TEMP' in desc or 'TERMO' in desc or 'HORNO' in desc:
        desc = 'TEMPERATURA'
    elif 'MEGOHM' in desc or 'ELECTRICIDAD' in desc or 'MULTIM' in desc or 'FUENTE' in desc or 'VOLTI' in desc or 'GAUSS' in desc or 'OHMMETER' in desc or 'AMPER' in desc or 'RESIS' in desc or 'CELDA' in desc or 'CRONO' in desc:
        desc = 'ELECTRICIDAD'
    elif 'BORO' in desc or 'EDDY' in desc or 'ULTRASON' in desc:
        desc = 'NDT'
    else:
        desc = 'OTROS'
    return desc

# %%
ds_complete['magnitud'] = ds_complete['description'].apply(lambda x: mag_identify(x))

# %%
ds_complete.magnitud.isnull().sum()
# Out:
# 0

# %%
test = 'TORQUIMETRO ANALÓGICO PROTO'
mag_identify(test)
# Out:
# 'TORQUE'

# %%
ds_complete.magnitud.value_counts()
# Out:
# DIMENSIONAL     741
# OTROS           581
# ELECTRICIDAD    272
# TEMPERATURA      99
# TORQUE           82
# PRESIÓN          39
# NDT              36
# Name: magnitud, dtype: int64

# %%
ds_complete.dtypes
# Out:
# TAT                   float64
# part_number            object
# description            object
# order_number           object
# vendor_code            object
# vendor_name            object
# Fe.contabilizaci¢n     object
# Centro de coste       float64
# costo_USD             float64
# unidad_USD             object
# costo_ARS             float64
# unidad_ARS             object
# Texto                  object
# magnitud               object
# dtype: object

# %%
magnitud_list = ds_complete.magnitud.unique()
print('-------PROMEDIO EN USD por MAGNITUD---------')
magnitudes_dic = {}
for mag in magnitud_list:
    filtro = ds_complete.magnitud == mag
    media_USD = ds_complete[filtro].costo_USD.std()
    magnitudes_dic[mag] = media_USD
    print(f'{mag}: {media_USD}')
# Out:
# -------PROMEDIO EN USD por MAGNITUD---------
# DIMENSIONAL: 240.01232714662683
# OTROS: 1075.7025401142014
# TORQUE: 160.8790648433257
# TEMPERATURA: 664.058131141644
# ELECTRICIDAD: 813.5045180952332
# PRESIÓN: 205.3438972663527
# NDT: 272.38043384732526

# %%
ds_complete[['costo_USD', 'magnitud']].describe()
# Out:
#           costo_USD
# count   1850.000000
# mean     302.377124
# std      740.696050
# min    -2818.000000
# 25%       65.667500
# 50%      115.000000
# 75%      244.750000
# max    12469.600000

# %%
cat_plot = sns.catplot(data=ds_complete, x='magnitud', y='costo_USD',  palette="ch:.25")
cat_plot.set_xticklabels(rotation=45)

# %%
def tiempos(mag):
    if mag == 'DIMENSIONAL':
        time = 5
    elif mag == 'PRESIÓN':
        time = 4
    elif mag == 'TORQUE':
        time = 4
    elif mag == 'OTROS':
        time = 5
    elif mag == 'TEMPERATURA':
        time = 5
    elif mag == 'ELECTRICIDAD':
        time = 5
    elif mag == 'NDT':
        time = 5
    
    return time

# %%
ds_complete['tiempo_calibracion'] = ds_complete.magnitud.apply(lambda x: tiempos(x))

# %%
ds_complete['costo_calibracion_lab'] = ds_complete.tiempo_calibracion.apply(lambda x: x * 60)

# %%
ds_complete.sample(3)
# Out:
#         TAT part_number        description order_number vendor_code  \
# 14192  97.0     436-3IN         MICROMETRO     R1534921      AR0011
# 1600   37.0     3.4-4IN  ALESAMETRO OPTICO     R2298821       7VKY4
# 5829   70.0        11IN            VARILLA     R0209122      AR0011
#
#                           vendor_name Fe.contabilizaci¢n  Centro de coste  \
# 14192  RUBEN HUGO COPPOLA E HIJOS SRL          19/1/2022       10501009.0
# 1600                   AVC LABORATORY           7/3/2022       10501009.0
# 5829   RUBEN HUGO COPPOLA E HIJOS SRL          21/4/2022       10501009.0
#
#        costo_USD unidad_USD  costo_ARS unidad_ARS    Texto     magnitud  \
# 14192      47.34        USD     5160.0        ARS  436-3IN  DIMENSIONAL
# 1600       80.00        USD     9060.0        ARS  3.4-4IN        OTROS
# 5829       48.67        USD     5792.0        ARS     11IN        OTROS
#
#        tiempo_calibracion  costo_calibracion_lab
# 14192                   5                    300
# 1600                    5                    300
# 5829                    5                    300

# %%
ds_complete[['costo_USD', 'costo_calibracion_lab']].sum()
# Out:
# costo_USD                559397.68
# costo_calibracion_lab    547740.00
# dtype: float64

# %%
ds_complete[['costo_USD', 'costo_calibracion_lab']].mean()
# Out:
# costo_USD                302.377124
# costo_calibracion_lab    296.075676
# dtype: float64

# %%
ds_complete.to_csv()
# Out:
# ',TAT,part_number,description,order_number,vendor_code,vendor_name,Fe.contabilizaci¢n,Centro de coste,costo_USD,unidad_USD,costo_ARS,unidad_ARS,Texto,magnitud,tiempo_calibracion,costo_calibracion_lab\r\n39,15.0,.800IN,MICROMETRO DE INTERIOR AXIAL,R0691121,AR0002,MITUTOYO SUL AMERICANA LTDA.,1/4/2022,10501009.0,106.03,USD,12300.0,ARS,.800IN,DIMENSIONAL,5,300\r\n50,45.0,43191,PARALELA,R1788221,AR0011,RUBEN HUGO COPPOLA E HIJOS SRL,28/1/2022,10501009.0,56.48,USD,6213.0,ARS,43191,DIMENSIONAL,5,300\r\n51,80.0,HCS203803C,BALANZA,R0044022,AR0507,CHACOMA S.A.,8/4/2022,10501009.0,159.91,USD,18750.0,ARS,HCS203803C,DIMENSIONAL,5,300\r\n52,13.0,UX100-003,DATALOGGER MARCA ONSET,R0433922,551CB,TRESCAL ESPAÑA DE METROLOGIA SLU,18/4/2022,10501009.0,97.58,USD,11311.02,ARS,UX100-003,OTROS,5,300\r\n53,42.0,UX100-003,DATALOGGER MARCA ONSET,R0433922,551CB,TRESCAL ESPAÑA DE METROLOGIA SLU,18/4/2022,10501009.0,97.58,USD,11311.02,ARS,UX100-003,OTROS,5,300\r\n54,482.0,780S-NAA-F7-EN2-P2-V,FLUJOMETRO,R0531622,US0954,ALPHA & OMEGA CALIBRATION SERVICES,21/6/2022,10501007.0,836.0,USD,106799.0,ARS,780S-NAA-F7-EN2-P2-V,OTROS,5,300\r\n55,482.0,780S-NAA-F7-EN2-P2-V,FLUJOMETRO,R0531622,US0954,ALPHA & OMEGA CALIBRATION SERVICES,21/6/2022,10501007.0,836.0,USD,106799.0,ARS,780S-NAA-F7-EN2-P2-V,OTROS,5,300\r\n56,61.0,PARALELAS,PARALELAS,R0689422,AR0011,RUBEN HUGO COPPOLA E HIJOS SRL,2/6/2022,10501007.0,63.87,USD,8000.0,ARS,PARALELAS,DIMENSIONAL,5,300\r\n57,55.0,0-1 IN.,MICROMETRO,R0852822,AR0011,RUBEN HUGO COPPOLA E HIJOS SRL,16/6/2022,10501007.0,29.51,USD,3770.0,ARS,0-1 IN.,DIMENSIONAL,5,300\r\n63,56.0,ID-C112EX,COMPARADOR,R2010422,AR0011,RUBEN HUGO COPPOLA E HIJOS SRL,15/11/2022,10501009.0,51.04,USD,8550.0,ARS,ID-C112EX,DIMENSIONAL,5,300\r\n105,195.0,2 IN,MICROMETRO,R1034321,AR0011,RUBEN HUGO COPPOLA E HIJOS SRL,18/1/2022,10501009.0,34.59,USD,3770.0,ARS,2 IN,DIMENSIONAL,5,300\r\n108,61.0,1.4 IN,ALESAMETRO OPTICO,R0015722,AR0011,RUBEN HUGO COPPOLA E HIJOS SRL,23/3/2022,10501009.0,70.35,USD,8108.0,ARS,1.4 IN,OTROS,5,300\r\n109,155.0,236TSDK,TORQUIMETRO,R0171422,AR0011,RUBEN HUGO COPPOLA E HIJOS SRL,13/7/2022,10501009.0,35.17,USD,4739.0,ARS,236TSDK,TORQUE,4,240\r\n110,13.0,THCD-100,CONFIGURABLE DISPLAY,R0213722,US0942,"BERNOULLI AEROSPACE, LLC",18/3/2022,10501009.0,75.0,USD,8587.5,ARS,THCD-100,OTROS,5,300\r\n112,41.0,THCD-100,CONFIGURABLE DISPLAY,R0213722,US0942,"BERNOULLI AEROSPACE, LLC",18/3/2022,10501009.0,75.0,USD,8587.5,ARS,THCD-100,OTROS,5,300\r\n114,33.0,LXB-A,DUROMETRO ANALOGICO - RANGO 0-100,R0427222,AR0229,N.R.Z. INSTRUMENTOS S.R.L.,13/4/2022,10501009.0,220.81,USD,26000.0,ARS,LXB-A,DIMENSIONAL,5,300\r\n115,460.0,RTR-52A,INDICADOR DE TEMP.,R0471722,AR0398,SICE S.R.L.,24/8/2022,10501009.0,215.65,USD,31000.0,ARS,RTR-52A,TEMPERATURA,5,300\r\n177,115.0,98F27003501-208,CINTA METRICA 2 METROS,R1315321,AR0011,RUBEN HUGO COPPOLA E HIJOS SRL,13/1/2022,10501009.0,26.14,USD,2843.0,ARS,98F27003501-208,DIMENSIONAL,5,300\r\n179,340.0,724,MONITOR,R1385221,AR0398,SICE S.R.L.,21/7/2022,10501009.0,132.6,USD,18000.0,ARS,724,OTROS,5,300\r\n185,47.0,IFR-4000,TST VOR/ILS/COMUNIC. RAMP TEST NAV,R2211521,US0942,"BERNOULLI AEROSPACE, LLC",7/3/2022,10501009.0,750.0,USD,84937.5,ARS,IFR-4000,OTROS,5,300\r\n186,13.0,IFR-4000,TST VOR/ILS/COMUNIC. RAMP TEST NAV,R2211521,US0942,"BERNOULLI AEROSPACE, LLC",7/3/2022,10501009.0,750.0,USD,84937.5,ARS,IFR-4000,OTROS,5,300\r\n188,205.0,30006-0050,DINAMOMETRO,R0226722,AR0011,RUBEN HUGO COPPOLA E HIJOS SRL,13/9/2022,10501009.0,139.46,USD,20744.0,ARS,30006-0050,DIMENSIONAL,5,300\r\n189,149.0,DPPH-150,DINAMOMETRO,R0227722,AR0011,RUBEN HUGO COPPOLA E HIJOS SRL,14/7/2022,10501009.0,153.66,USD,20744.0,ARS,DPPH-150,DIMENSIONAL,5,300\r\n190,51.0,24IN.,CINTA PROMEDIADORA,R0540422,AR0011,RUBEN HUGO COPPOLA E HIJOS SRL,4/5/2022,10501009.0,61.79,USD,7476.0,ARS,24IN.,DIMENSIONAL,5,300\r\n191,72.0,C21,COMPARADOR,R0766722,AR0011,RUBEN HUGO COPPOLA E HIJOS SRL,29/6/2022,10501009.0,30.84,USD,4001.0,ARS,C21,DIMENSIONAL,5,300\r\n196,7.0,M309,CRIMPING TOOL,R1401222 ...
